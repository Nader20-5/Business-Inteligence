# %%
#  IMPORT LIBRARIES
#import pandas as pd
#import numpy as np
#import matplotlib.pyplot as plt
#import seaborn as sns
#from mlxtend.frequent_patterns import fpgrowth
#from mlxtend.frequent_patterns import association_rules
#----------------------------
# LOAD DATASET
#file_path = 'Groceries_dataset.csv'
#df = pd.read_csv(file_path)
#print(" Dataset Loaded Successfully")
#print(f"Shape: {df.shape}")
#-----------------------------

# PREPROCESSING]cx
#print("\n-Starting Preprocessing: ")

# Group by Member and Date to create a 'Transaction'
#basket = (df.groupby(['Member_number', 'Date', 'itemDescription'])['itemDescription']
          #.count().unstack().reset_index().fillna(0)
          #.set_index(['Member_number', 'Date']))

# Convert counts to Boolean (0 or 1)
#def encode_units(x):
    #if x <= 0:
        #return 0
    #if x >= 1:
        #return 1

#basket_sets = basket.applymap(encode_units)

#print(" Data Transformed to Market Basket Format")
#print(f"Transformed Shape: {basket_sets.shape}")
#-----------------------------------

# TRAIN MODEL (FP-GROWTH)
#print("\n Training FP-Growth Model ")
# Generate Frequent Itemsets (Min Support 0.1%)
#frequent_itemsets = fpgrowth(basket_sets, min_support=0.001, use_colnames=True)
#print(" Frequent Itemsets Generated")
#print(f"Count of Frequent Itemsets: {len(frequent_itemsets)}")
#-------------------------------------

# PREDICTION (RULE GENERATION)
# Generate rules based on Lift > 1
#rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)
# Sort rules by Lift
#rules = rules.sort_values(by='lift', ascending=False)
#print(f" Association Rules Generated: {len(rules)}")
# Display Top 5 Rules (Raw Format)
#print("\n Top 5 Strongest Rules ")
#print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].head(5))
#----------------------------------------


# STEP 7: EVALUATION
#print("\n Model Evaluation: ")
#print(rules[['support', 'confidence', 'lift']].describe())
#----------------------------------------

# STEP 8: CONCLUSION
#print("\n Conclusion: ")
#if not rules.empty:
    #best_rule = rules.iloc[0]
    # Note: Accessing frozenset items
    #ant = list(best_rule['antecedents'])[0]
    #con = list(best_rule['consequents'])[0]
    #lift = best_rule['lift']
    
    #print("The FP-Growth algorithm successfully identified shopping patterns.")
    #print(f"Insight: The strongest relationship is between '{ant}' and '{con}'.")
    #print(f"Lift: {lift:.4f}")
#else:
    #print("No significant rules found.")
# Out:
#  Dataset Loaded Successfully
# Shape: (38765, 3)
#
# -Starting Preprocessing:
# C:\Users\loaya\AppData\Local\Temp\ipykernel_19736\432757136.py:33: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   basket_sets = basket.applymap(encode_units)
#  Data Transformed to Market Basket Format
# Transformed Shape: (14963, 167)
#
#  Training FP-Growth Model
# d:\BI project\.venv\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#  Frequent Itemsets Generated
# Count of Frequent Itemsets: 750
#  Association Rules Generated: 240
#
#  Top 5 Strongest Rules
#               antecedents            consequents   support  confidence  \
# 14              (sausage)   (whole milk, yogurt)  0.001470    0.024363
# 11   (whole milk, yogurt)              (sausage)  0.001470    0.131737
# 10  (whole milk, sausage)               (yogurt)  0.001470    0.164179
# 15               (yogurt)  (whole milk, sausage)  0.001470    0.017121
# 80  (specialty chocolate)         (citrus fruit)  0.001403    0.087866
#
#         lift
# 14  2.182917
# 11  2.182917
# 10  1.911760
# 15  1.911760
# 80  1.653762
#
#  Model Evaluation:
#           support  confidence        lift
# count  240.000000  240.000000  240.000000
# mean     0.001612    0.055186    1.186579
# std      0.000881    0.042429    0.191060
# min      0.001002    0.006771    1.000136
# 25%      0.001136    0.024330    1.051529
# 50%      0.001370    0.041638    1.122790
# 75%      0.001671    0.074008    1.253237
# max      0.005948    0.255814    2.182917
#
#  Conclusion:
# The FP-Growth algorithm successfully identified shopping patterns.
# Insight: The strongest relationship is between 'sausage' and 'whole milk'.
# Lift: 2.1829

# %%
#  IMPORT LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules

# %%
#LOAD DATASET
file_path = 'Groceries_dataset.csv'
df = pd.read_csv(file_path)

print(" Dataset Loaded Successfully")
print(f"Shape: {df.shape}")

# %%
# PREPROCESSING]cx
print("\n-Starting Preprocessing: ")

# Group by Member and Date to create a 'Transaction'
basket = (df.groupby(['Member_number', 'Date', 'itemDescription'])['itemDescription']
          .count().unstack().reset_index().fillna(0)
          .set_index(['Member_number', 'Date']))

# Convert counts to Boolean (0 or 1)
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)

print(" Data Transformed to Market Basket Format")
print(f"Transformed Shape: {basket_sets.shape}")

# %%
# TRAIN MODEL (FP-GROWTH)
print("\n Training FP-Growth Model ")

# Generate Frequent Itemsets (Min Support 0.1%)
frequent_itemsets = fpgrowth(basket_sets, min_support=0.001, use_colnames=True)

print(" Frequent Itemsets Generated")
print(f"Count of Frequent Itemsets: {len(frequent_itemsets)}")

# %%
# PREDICTION (RULE GENERATION)

# Generate rules based on Lift > 1
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)

# Sort rules by Lift
rules = rules.sort_values(by='lift', ascending=False)

print(f" Association Rules Generated: {len(rules)}")

# Display Top 5 Rules (Raw Format)
print("\n Top 5 Strongest Rules ")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].head(5))

# %%
# STEP 7: EVALUATION
print("\n Model Evaluation: ")
print(rules[['support', 'confidence', 'lift']].describe())

# %%
# STEP 8: CONCLUSION
print("\n Conclusion: ")
if not rules.empty:
    best_rule = rules.iloc[0]
    # Note: Accessing frozenset items
    ant = list(best_rule['antecedents'])[0]
    con = list(best_rule['consequents'])[0]
    lift = best_rule['lift']
    
    print("The FP-Growth algorithm successfully identified shopping patterns.")
    print(f"Insight: The strongest relationship is between '{ant}' and '{con}'.")
    print(f"Lift: {lift:.4f}")
else:
    print("No significant rules found.")
